# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = {
    "House Size (sqft)": [850, 4200, 1180, 6300, 920, 3800, 2100, 750, 4900, 1100, 6800, 2600, 900, 5900, 1300, 8100, 3000, 4500, 1800, 9900, 2200, 1200, 5100, 7500, 2800, 6200, 1000, 8800, 3500, 9200, 2000, 10500, 4000, 7800, 2400],
    "House Price ($)": [225000, 729000, 89430, 95000, 139030, 595000, 319000, 118600, 805000, 1657000, 1225000, 395000, 135000, 575000, 429000, 680000, 429000, 675000, 279000, 1425000, 329000, 185000, 779000, 950000, 415000, 925000, 149000, 1300000, 529000, 1350000, 309000, 1600000, 599000, 1150000, 359000]
}
df = pd.DataFrame(data)
X = df["House Size (sqft)"]
y = df["House Price ($)"]

# %%
# Step 2: Visualize the dataset
X =  df["House Size (sqft)"]
y = df["House Price ($)"]
plt.scatter(X, y, color='blue')
z = np.polyfit(X, y, 1)
p = np.poly1d(z)
plt.plot(X, p(X), "r--")
plt.xlabel("House Size (sqft)")
plt.ylabel("House Price ($)")
plt.title("House Size vs House Price")
plt.show()
